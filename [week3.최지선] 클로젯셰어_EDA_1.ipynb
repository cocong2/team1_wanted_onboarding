# %% [markdown]
# # 클로젯셰어 수행 과제
# ## Main Theme : 신규 구매 전반 분석 및 결과 도식화
#
# - 분석 자료 : 최근 3개월간 신규 구매 데이터 일부
#
# - 분석 필요 내용
#
#   1. 구매 소요 시간 분석
#      1-1. 가입일로부터 구매일까지 전환된 소요시간 분석
#          ㄴ 최근 3개월 전체 분석 / 각 월 별 분석
#          ㄴ 분기 경향 / 월 별 변동사항 확인 -> 트렌드 분석
#             ex. 가입 1일 이내 전환 유저 : 10% -> 15% 상승 성과
#   2. 구매 상품 트렌드 분석
#      2-1. 유저당 주문 수량 분석
#          ㄴ 최근 3개월 전체 분석 / 각 월 별 분석
#          ㄴ 분기 경향 / 월 별 변동사항 확인 -> 트렌드 분석
#
#      2-2. 주문 아이템 분석
#          ㄴ 브랜드 별 선호도, 아이템 카테고리별 선호도 분석
#          ㄴ 신규 유저들의 구매 트렌드 파악
# 3. 분석 내용 토대로 인사이트 도출
#      3-1. 분석 내용 도식화
#          ㄴ 1~2의 분석 내용 종합 및 도식화 (표 또는 그래프)
#          ㄴ 유사성을 갖는 결과에 대하여 그룹화
#      3-2. 인사이트 도출
#          ㄴ 해당 결과를 통해 나타나는 사항 정리
#          ㄴ 인사이트 도출 혹은 새로운 제안사항 전달 (없을 시 진행하지 않아도 무방)
#
# - 분석 참고 사항
#
#   1. 용어 및 칼럼 설명
#      brandnm : 아이템 브랜드명
#      goodsnm : 아이템 명
#      USER : 개별 유저 식별 값
#      reg_date : 개별 유저 가입일
#      order_date : 아이템 주문일
#      p_type : 주문 상품 종류
#              7days (7일권) / 4days (4일권)
#      sub_type : 주문 상품 카테고리
#                BA – 가방 / O – 아우터 / D – 드레스 / T – 상의 / B – 하의 / TB – 투피스
#      app_yn : 어플리케이션 사용 여부
#               Y – 어플리케이션 사용 / (공백) – 어플리케이션 미사용

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import warnings
warnings.filterwarnings(action='ignore')

#한글 폰트 설정
plt.rcParams['font.family'] = 'HYGothic-Extra'

# %%
def get_font_family():
    """
    시스템 환경에 따른 기본 폰트명을 반환하는 함수
    """
    import platform
    system_name = platform.system()
    # colab 사용자는 system_name이 'Linux'로 확인

    if system_name == "Darwin" :
        font_family = "AppleGothic"
    elif system_name == "Windows":
        font_family = "Malgun Gothic"
    else:
        # Linux
        # colab에서는 runtime을 <꼭> 재시작 해야함.
        # 런타임을 재시작 하지 않고 폰트 설치를 하면 기본 설정 폰트가 로드되어 한글이 깨짐.
        # !apt-get update -qq
        # !apt-get install fonts-nanum -qq  > /dev/null

        import matplotlib.font_manager as fm

        fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
        font = fm.FontProperties(fname=fontpath, size=9)
        fm._rebuild()
        font_family = "NanumBarunGothic"
    return font_family

# %%
# 시각화를 위한 폰트설정
# 위에서 만든 함수를 통해 시스템 폰트를 불러와서 font_family 라는 변수에 할당.
a = get_font_family()
# 폰트설정
import matplotlib.pyplot as plt 
plt.rc("font", family = a)
# 마이너스폰트 설정
plt.rc("axes", unicode_minus=False)
# ggplot으로 그래프 스타일 설정 / 개인 자유
plt.style.use("ggplot")

# %% [markdown]
# ## 데이터 불러오기

# %%
df_raw = pd.read_csv('클로젯셰어_과제DB 대체 자료.csv', encoding='cp949')
df_raw
# Out:
#                   brandnm                                    goodsnm  \
# 0                   Gucci         flower dionysus shoulder bag beige
# 1     El estilo de Claire                 beads cropped jacket black
# 2                   Danha  embroidery point oriental mini skirt blue
# 3                   Danha                  graphics pattern top pink
# 4         Burberry London     buckle basic pattern zipup-jumper navy
# ...                   ...                                        ...
# 1466   Yves Saint Laurent                 logo point clutch bag pink
# 1467                Prada                        saffiano lux M gray
# 1468             Burberry                basic pattern sweater beige
# 1469               Chanel        graphics pattern sweat-shirts white
# 1470             Burberry                  classic trench coat beige
#
#           USER    reg_date  order_date p_type sub_type app_yn
# 0      a161237  2019-12-06  2021-01-15  7days       BA      Y
# 1     a1140859  2021-01-02  2021-01-15  4days        O    NaN
# 2     a1140859  2021-01-02  2021-01-15  4days        B    NaN
# 3     a1140859  2021-01-02  2021-01-15  4days        T    NaN
# 4     a1140740  2021-01-01  2021-01-15  7days        O      Y
# ...        ...         ...         ...    ...      ...    ...
# 1466   a119721  2019-04-10  2021-03-01  7days       BA      Y
# 1467  a1146069  2021-02-11  2021-03-01  7days       BA      Y
# 1468  a1147848  2021-02-28  2021-03-01  7days        T      Y
# 1469  a1147788  2021-02-28  2021-03-01  7days        T      Y
# 1470   a190054  2020-03-24  2021-03-01  4days        O      Y
#
# [1471 rows x 8 columns]

# %%
df_raw_copy = df_raw

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1471 entries, 0 to 1470
# Data columns (total 8 columns):
# brandnm       1442 non-null object
# goodsnm       1471 non-null object
# USER          1471 non-null object
# reg_date      1466 non-null object
# order_date    1471 non-null object
# p_type        1471 non-null object
# sub_type      1471 non-null object
# app_yn        1295 non-null object
# dtypes: object(8)
# memory usage: 92.1+ KB

# %%
df_raw.describe()
# Out:
#        brandnm                          goodsnm      USER    reg_date  \
# count     1442                             1471      1471        1466
# unique     245                              979      1234         368
# top      Gucci  chevron quilted cross bag black  a1149461  2021-03-16
# freq       232                               23        11          44
#
#         order_date p_type sub_type app_yn
# count         1471   1471     1471   1295
# unique          90      2        6      1
# top     2021-03-24  4days       BA      Y
# freq            47    894      692   1295

# %%
df_raw.isnull().sum()
# Out:
# brandnm        29
# goodsnm         0
# USER            0
# reg_date        5
# order_date      0
# p_type          0
# sub_type        0
# app_yn        176
# dtype: int64

# %% [markdown]
# **결측치가 브랜드명과 앱사용여부에 존재함**
# 앱사용여부는 결측치는 N이므로 결측치 대체 가능
# 브랜드명은 어떻게 결측치 대체할껀지?

# %%
# 앱사용여부 결측치 'N' 대체
df_raw_copy['app_yn'] = df_raw_copy['app_yn'].fillna('N')
df_raw_copy
# Out:
#                   brandnm                                    goodsnm  \
# 0                   Gucci         flower dionysus shoulder bag beige
# 1     El estilo de Claire                 beads cropped jacket black
# 2                   Danha  embroidery point oriental mini skirt blue
# 3                   Danha                  graphics pattern top pink
# 4         Burberry London     buckle basic pattern zipup-jumper navy
# ...                   ...                                        ...
# 1466   Yves Saint Laurent                 logo point clutch bag pink
# 1467                Prada                        saffiano lux M gray
# 1468             Burberry                basic pattern sweater beige
# 1469               Chanel        graphics pattern sweat-shirts white
# 1470             Burberry                  classic trench coat beige
#
#           USER    reg_date  order_date p_type sub_type app_yn
# 0      a161237  2019-12-06  2021-01-15  7days       BA      Y
# 1     a1140859  2021-01-02  2021-01-15  4days        O      N
# 2     a1140859  2021-01-02  2021-01-15  4days        B      N
# 3     a1140859  2021-01-02  2021-01-15  4days        T      N
# 4     a1140740  2021-01-01  2021-01-15  7days        O      Y
# ...        ...         ...         ...    ...      ...    ...
# 1466   a119721  2019-04-10  2021-03-01  7days       BA      Y
# 1467  a1146069  2021-02-11  2021-03-01  7days       BA      Y
# 1468  a1147848  2021-02-28  2021-03-01  7days        T      Y
# 1469  a1147788  2021-02-28  2021-03-01  7days        T      Y
# 1470   a190054  2020-03-24  2021-03-01  4days        O      Y
#
# [1471 rows x 8 columns]

# %% [markdown]
# ### 최근구입일 - 가입일 기간 새로운 변수 생성

# %%
# 가입일과 구매일을 datetime으로..
df_raw_copy['reg_date'] = pd.to_datetime(df_raw_copy['reg_date'])
df_raw_copy['order_date'] = pd.to_datetime(df_raw_copy['order_date'])

df_raw_copy['order_month'] = df_raw_copy['order_date'].dt.strftime('%m')
df_raw_copy['period'] = df_raw_copy['order_date']-df_raw_copy['reg_date']

# %%
df_raw_copy.describe()
# Out:
#                          period
# count                      1466
# mean   106 days 21:02:12.605729
# std    206 days 21:18:13.894908
# min             0 days 00:00:00
# 25%             1 days 00:00:00
# 50%             4 days 00:00:00
# 75%            88 days 00:00:00
# max          1304 days 00:00:00

# %%
len(df_raw_copy['USER'].unique())
# Out:
# 1234

# %% [markdown]
# >**전체 유저 수는 1234명**

# %%
# 가입하고 당일에 구입한 유저 수
df_raw_copy_0user = df_raw_copy.loc[df_raw_copy['period']=='0 days']

df_raw_copy_0user['period'] = df_raw_copy_0user['period'].dt.days
df_raw_copy_0user
# Out:
#               brandnm                                      goodsnm      USER  \
# 15              Prada                          logo hobo bag black  a1143143
# 16              Gucci          microssima mini cross body bag pink  a1142921
# 17               Time              pocket basic pattern coat black  a1142921
# 22    & Other Stories                  basic pattern sweater ivory  a1143019
# 30              Prada                 quilted cross body bag black  a1142924
# ...               ...                                          ...       ...
# 1458           Chanel                      boy chanel clutch black  a1147960
# 1461           Chanel      pocket tweed pattern cashmere coat pink  a1147959
# 1463         Burberry               check mackenzie cross bag pink  a1147938
# 1464  Burberry London  embroidery basic pattern wool sweater brown  a1147932
# 1465       London Fog               button basic pattern coat grey  a1147932
#
#        reg_date order_date p_type sub_type app_yn order_month period
# 15   2021-01-15 2021-01-15  4days       BA      Y          01 0 days
# 16   2021-01-14 2021-01-14  4days       BA      Y          01 0 days
# 17   2021-01-14 2021-01-14  4days        O      Y          01 0 days
# 22   2021-01-14 2021-01-14  4days        T      N          01 0 days
# 30   2021-01-14 2021-01-14  4days       BA      Y          01 0 days
# ...         ...        ...    ...      ...    ...         ...    ...
# 1458 2021-03-01 2021-03-01  7days       BA      Y          03 0 days
# 1461 2021-03-01 2021-03-01  7days        O      N          03 0 days
# 1463 2021-03-01 2021-03-01  7days       BA      Y          03 0 days
# 1464 2021-03-01 2021-03-01  4days        T      Y          03 0 days
# 1465 2021-03-01 2021-03-01  4days        O      Y          03 0 days
#
# [349 rows x 10 columns]

# %%
len(df_raw_copy_0user['USER'].unique()) # 당일 가입 구매 유저
# Out:
# 320

# %% [markdown]
# ### 가입 당일 앱 사용한 유저들의 경향

# %%
# 어떤 브랜드 이용?

df_raw_copy_0user

plt.figure(figsize=(25,12))
color = sns.set_palette("Pastel2")
sns.countplot(df_raw_copy_0user['brandnm'], palette=color)
plt.grid()
plt.title('가입 당일 구매한 유저들의 브랜드 이용', fontsize=25)
plt.ylabel('이용건수', fontsize=20)
plt.xlabel('브랜드명', fontsize=20)
plt.show()

# %%
# 전체 데이터의 브랜드명 개수

print(len(df_raw_copy['brandnm'].unique()))
df_raw_copy['brandnm'].unique()
# Out:
# 246
# array(['Gucci', 'El estilo de Claire', 'Danha', 'Burberry London',
#        'Prada', 'Max Mara', 'Molliolli', 'Sandro', 'Louis Vuitton',
#        'Tory Burch', 'Chloe', 'Time', 'The Izzat', 'Mojosphine',
#        'Ted Baker', '& Other Stories', 'Fendi', 'Balmain', 'Celine',
#        'Burberry', 'Chanel', 'Dior', 'Bottega Veneta', 'Plastic Island',
#        'Reneevon', 'Sorry Too Much Love', 'Saint Laurent', 'Miu Miu',
#        'Yves Saint Laurent', 'Zooc', 'Vivienne Westwood',
#        'Maison Kitsune', 'Margarin fingers', 'The Tint', 'Love Moschino',
#        'Michaa', 'Vivienne Westwood Red Label', 'MSGM', 'Christian Dior',
#        'It michaa', 'SJSJ', 'Amsale', 'Imvely', 'Chi Chi London', 'Maje',
#        'Biker Starlet', 'Thom Browne', 'Jill By Jill Stuart',
#        'Comme des Garcons', 'Nain', 'Dolce & Gabbana', 'Givenchy',
#        'Salvatore Ferragamo', 'Andersen-Andersen', 'A.P.C.',
#        'Self-portrait', 'Sonia Rykiel', 'Diane von Furstenberg',
#        'Hugo Boss', 'Baum Und Pferdgarten', 'BCBG', 'Lmml Studio', 'Nike',
#        'Not Your Rose', nan, 'Jigott', 'Escada', 'Diagonal', 'System',
#        'On&On', 'Lucky Chouette', 'The Clozet', 'Allen.O', 'Vunque',
#        'Jill Stuart', 'Egoist', 'Johnny Hates Jazz', 'Moschino', 'Ami',
#        'BCBG Max Azria', 'S blanc', 'Michael Michael Kors',
#        'Spring Crocus', 'Allsaints', 'Theory', 'Polo Ralph Lauren',
#        'Balenciaga', 'Fayewoo', 'Eight Slate', 'ACNE STUDIOS', 'Cos',
#        'Adidas X Stella Mccartney', 'Wonder Style', 'Versace', 'Sacai',
#        'H&Moschino', 'Delvaux', 'More Or Less', 'khrisjoy', 'Mulberry',
#        'JDC Lucky Chouette', 'Jacquemus', 'Marni', 'DKNY',
#        'Isabel Marant', 'DELLEST', 'Lanvin', 'Maison Margiela',
#        'Greedilous', 'System homme', 'Covernat', 'Musinsa standard',
#        'Lafudge Store', 'Calvin Klein', 'Massimo Dutti', 'Inusway',
#        'Banana Republic', 'Audrey Tailor', 'Vanessa Bruno Athe', 'A BY A',
#        'Isabel Marant Etoile', 'Akro', 'Armani Collezioni', 'Play Nomore',
#        'Heohwan Simulation', 'Kenzo', 'Valentino', 'Rimowa',
#        'Opening Ceremony', 'cecilie bahnsen', 'Mine', 'Olive des Olive',
#        'Jil Sander', 'The Centaur', 'Leah', 'Rosa.K', 'Adidas', 'Bulgari',
#        'Becla', 'Pure DKNY', 'Ambush', 'Hacie', 'Nobis', 'Moncler',
#        'Cesare Paciotti', 'Stella Mccartney', 'Ava Molli', 'MYEYEKO',
#        'Dewl', 'Minimarket black', 'Helmut Lang', 'Luv is True',
#        'Collabotory', 'Goyard', 'Burberry Brit',
#        'Frontrow x maison marais', 'Paule Ka', 'Dolly Girl Anna Sui',
#        'Convexo Concave', 'Boss', 'Wai Kei', 'EYEYE', 'Beaker',
#        'Canada Goose', 'Rebecca Minkoff', 'Vince', 'Coach',
#        'Overdueflair', 'Off White', 'Marc New York', 'Aspesi', 'VOV',
#        'Time homme', 'Ralph Lauren', 'Carven', 'thom browne', 'Rouje',
#        'BYREDO', 'Alexander Mcqueen', 'Stylenanda', 'McGinn',
#        'Lanvin Collection', 'Since then', 'Studio Tomboy', 'Sisley',
#        'At Corner', 'Essentiel Antwerp', 'Lookast', 'Alexander Wang',
#        'Hackesch', 'Jucy Judy', 'And You', 'Dint', 'Bar Bour',
#        'Andersson Bell', 'Paul Smith', 'Moia', 'Your Name Here', 'Ruhm',
#        'Nohant', 'Lenic & Mccoy', 'Hermes', 'Marco De Vincenzo',
#        'Galon de Blanc', 'Daze Dayz', 'Anne Klein', 'Debb', 'C.holyn',
#        'Karl Lagerfeld', 'Zadig & Voltaire', 'La maille sezane',
#        'Pearly gates golf', 'Low classic', 'Furla', 'Alice & Olivia',
#        'roajeu', 'Frontrow', 'Markus Lupfer', 'Elizabeth & James',
#        'Victoria Bay', 'Reiss', 'Red Valentino', 'Rogervivier',
#        'Nice Claup', 'L’ vir', 'Stay with me', 'Stefanel',
#        'Vanessa Bruno', 'SYZ', 'Tommy Hilfiger', 'Chee U',
#        'Salon De yohn', 'Recto.', 'Etro', 'SJYP', 'Oh L', 'Anna Sui',
#        'Calvin Klein Jeans', 'Bourie', 'OiOi', 'SDI', 'BEMUSE MANSION',
#        'Clu', 'Paipai jiemei', 'EJnolee', 'London Fog'], dtype=object)

# %%
df_raw_copy['brandnm'].value_counts().head(10) # 전체 데이터의 top10
# Out:
# Gucci                 232
# Chanel                 90
# Saint Laurent          86
# Louis Vuitton          79
# Prada                  58
# Burberry               53
# Yves Saint Laurent     38
# Thom Browne            33
# Fendi                  29
# Celine                 28
# Name: brandnm, dtype: int64

# %%
# 당일 가입 구매 유저의 브랜드 선호도 top10

df_raw_copy_0user['brandnm'].value_counts().head(10)
# Out:
# Gucci                 73
# Saint Laurent         34
# Chanel                30
# Louis Vuitton         26
# Prada                 14
# Burberry              12
# Yves Saint Laurent    11
# Celine                10
# Thom Browne            8
# Christian Dior         5
# Name: brandnm, dtype: int64

# %% [markdown]
# #### 전체 유저의 브랜드 선호도와 큰 차이는 없는 듯

# %%
# 이용 카테고리?
df_raw_copy_0user

plt.figure(figsize=(25,12))
color = sns.set_palette("Pastel2")
sns.countplot(df_raw_copy_0user['sub_type'], palette=color)
plt.grid()
plt.title('가입 당일 구매한 카테고리', fontsize=25)
plt.ylabel('이용건수', fontsize=20)
plt.xlabel('카테고리', fontsize=20)
plt.show()

# %% [markdown]
# **1위 가방(BA)**
# 그 다음 아우터(O), 드레스(D) 순
# 제일 이용건수가 적은 카테고리는 하의(B)

# %% [markdown]
# #### 그럼 구찌 이용이 많은건 구찌 브랜드의 가방이나 아우터 드레스 보유가 많아서 일까?

# %%
## 브랜드 구찌가 많이 보유하고 있는 카테고리?

df_raw_copy

plt.figure(figsize=(25,12))
color = sns.set_palette("Pastel2")
sns.countplot(x = df_raw_copy['sub_type'], data = df_raw_copy.loc[df_raw_copy['brandnm'] =='Gucci'], palette=color)
plt.grid()
plt.title('가입 당일 구매한 카테고리', fontsize=25)
plt.ylabel('이용건수', fontsize=20)
plt.xlabel('카테고리', fontsize=20)
plt.show()

# %% [markdown]
# **실제로 구찌 브랜드에서 가방(BA) 카테고리 보유가 많음**

# %% [markdown]
# #### 그럼 가입기간이 가장 긴 유저와 당일 가입한 유저들의 구매 브랜드와 구매상품 차이 확인

# %%
df_raw_copy_75peruser = df_raw_copy.loc[df_raw_copy['period']>='88 days']
df_raw_copy_75peruser
# Out:
#                  brandnm                                  goodsnm     USER  \
# 0                  Gucci       flower dionysus shoulder bag beige  a161237
# 5                  Prada                  ruffle detail long coat  a110231
# 7              Molliolli     pocket basic pattern fur-outer ivory  a115159
# 9                 Sandro           pattern pointed cardigan black  a117306
# 27                 Fendi                 two way bucket bag white  a192991
# ...                  ...                                      ...      ...
# 1454            Burberry  button basic pattern wool cardigan grey  a163815
# 1459               Gucci      marmont gg logo quilted bag Black 2  a177034
# 1462            Max Mara            zipper detail two tone jacket  a112319
# 1466  Yves Saint Laurent               logo point clutch bag pink  a119721
# 1470            Burberry                classic trench coat beige  a190054
#
#        reg_date order_date p_type sub_type app_yn order_month   period
# 0    2019-12-06 2021-01-15  7days       BA      Y          01 406 days
# 5    2018-10-18 2021-01-15  7days        O      Y          01 820 days
# 7    2019-01-29 2021-01-15  4days        O      Y          01 717 days
# 9    2019-03-02 2021-01-15  7days        O      Y          01 685 days
# 27   2020-04-02 2021-01-14  7days       BA      Y          01 287 days
# ...         ...        ...    ...      ...    ...         ...      ...
# 1454 2019-12-12 2021-03-01  7days        O      Y          03 445 days
# 1459 2020-01-23 2021-03-01  4days       BA      Y          03 403 days
# 1462 2018-11-29 2021-03-01  4days        O      Y          03 823 days
# 1466 2019-04-10 2021-03-01  7days       BA      Y          03 691 days
# 1470 2020-03-24 2021-03-01  4days        O      Y          03 342 days
#
# [371 rows x 10 columns]

# %%
print(len(df_raw_copy_75peruser['USER'].unique()))  # 가입일이 오래된 유저(사분위수 75% 이상)
# Out:
# 303

# %%
# 가입일이 오래된 유저의 브랜드 선호도 top10

df_raw_copy_75peruser['brandnm'].value_counts().head(10)
# Out:
# Gucci                 37
# Chanel                19
# Burberry              19
# Prada                 16
# Louis Vuitton         13
# Saint Laurent         13
# Yves Saint Laurent    11
# Thom Browne           11
# Max Mara               9
# Fendi                  8
# Name: brandnm, dtype: int64

# %% [markdown]
# ### 전체 데이터의 브랜드 순위와 조금 다르다는 것을 알 수 있음

# %% [markdown]
# *가입일이 오래되었다는 것이 오랜만에 구입한건지 꾸준히 구입해 온건지 구매횟수를 살펴봐야 할 것 같다
# *두 그룹으로(당일구매/오래전가입구매) 나누어 앱사용여부나 구매권을 더 상세히 살펴볼 필요

# %%
df_raw_copy['day'] = df_raw_copy['order_date'].dt.weekday # 0(월) ~ 6(일)

# %%
# 요일별 상품별 결제건수

df_raw_copy_d_p = df_raw_copy.groupby(['day','p_type'])['USER'].count().reset_index()
df_raw_copy_d_p = df_raw_copy_d_p[['day','p_type','USER']]
df_raw_copy_d_p.columns = ['요일','상품','이용수']
df_raw_copy_d_p
# Out:
#     요일     상품  이용수
# 0    0  4days  126
# 1    0  7days   77
# 2    1  4days  178
# 3    1  7days  113
# 4    2  4days  236
# 5    2  7days   96
# 6    3  4days  170
# 7    3  7days  115
# 8    4  4days  117
# 9    4  7days   78
# 10   5  4days   27
# 11   5  7days   35
# 12   6  4days   40
# 13   6  7days   63

# %%
fig, ax = plt.subplots(1,1, figsize = (15,8))
sns.pointplot(x = '요일', y = '이용수', hue = '상품', data = df_raw_copy_d_p, palette = color)
plt.title('요일별 상품 이용', fontsize = 20, fontweight = 'bold')
plt.xlabel('요일', fontsize = 12, fontweight = 'bold')
plt.ylabel('이용 수', fontsize = 12, fontweight = 'bold')
plt.tick_params(axis = 'x', labelsize = 12)
plt.tick_params(axis = 'y', labelsize = 12)
fig.show()

# %% [markdown]
# **4일권/7일권 모두 토요일에 감소**
# 가방 쉐어가 많은 것을 봤을 때, 결혼식이나 주말에 있을 행사때문에 사용하려나?
# 하고 생각했었는데, 결제요일이 실제로 결제한 날인지.. 사용한 날인지.. 또 생각하게 됨

# %% [markdown]
# **기타사항**
# 후기 : https://m.blog.naver.com/CommentList.nhn?blogId=greanb&logNo=221827174188
# (구글에 클로제셰어 검색하면 단점이 상단에 뜸..)
# 최근 댓글 읽어보았는데, 수수료도 크고 CS 대응도 좋지 않은듯 함 상품관리도 소홀
# 당장에 이익내는것도 중요하지만 사람들을 많이 끌어모으고 이탈하지 않는 방법 고민 필요
#
# ---------------------------
# * 쉐어러들은 왜 자신의 물건을 쉐어할까?
# * 이용자들은 왜 상품을 구매하지 않고 빌려서 사용할까?
#   - 다양한 브랜드 사용해보고 싶어서?
#   - 구매 전 시착용?
